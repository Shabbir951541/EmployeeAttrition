# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, confusion_matrix

# Load the dataset
df = pd.read_csv("D:\Personal projects\EMPLOYEE ATTRITION\EAA\HR-Employee-Attrition.csv")

# Encode categorical variables as binary values
df = pd.get_dummies(df, columns=["BusinessTravel", "Department", "EducationField", "Gender", "JobRole", "MaritalStatus", "OverTime", "Over18"])

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(df.drop("Attrition", axis=1), df["Attrition"], test_size=0.2, random_state=42)

# Train a decision tree classifier
model = DecisionTreeClassifier()
model.fit(X_train, y_train)

# Make predictions on the testing set
y_pred = model.predict(X_test)

# Evaluate the accuracy of the model
acc = accuracy_score(y_test, y_pred)
print("Accuracy:", acc)

# Print the confusion matrix
cm = confusion_matrix(y_test, y_pred)
print("Confusion matrix:")
print(cm)
# Out:
# Accuracy: 0.7789115646258503
# Confusion matrix:
# [[221  34]
#  [ 31   8]]

# %%
pip install graphviz
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# Collecting graphviz
#   Downloading graphviz-0.20.1-py3-none-any.whl (47 kB)
#      ---------------------------------------- 47.0/47.0 kB 2.3 MB/s eta 0:00:00
# Installing collected packages: graphviz
# Successfully installed graphviz-0.20.1

# %%
from sklearn.tree import export_text

# Export the tree as text
tree_rules = export_text(model, feature_names=list(X_train.columns))

# Print the tree
print(tree_rules)
# Out:
# |--- OverTime_No <= 0.50
# |   |--- MonthlyIncome <= 2475.00
# |   |   |--- DailyRate <= 931.00
# |   |   |   |--- Age <= 36.00
# |   |   |   |   |--- TrainingTimesLastYear <= 5.50
# |   |   |   |   |   |--- class: Yes
# |   |   |   |   |--- TrainingTimesLastYear >  5.50
# |   |   |   |   |   |--- class: No
# |   |   |   |--- Age >  36.00
# |   |   |   |   |--- EducationField_Medical <= 0.50
# |   |   |   |   |   |--- class: Yes
# |   |   |   |   |--- EducationField_Medical >  0.50
# |   |   |   |   |   |--- YearsInCurrentRole <= 2.50
# |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |--- YearsInCurrentRole >  2.50
# |   |   |   |   |   |   |--- class: Yes
# |   |   |--- DailyRate >  931.00
# |   |   |   |--- YearsInCurrentRole <= 2.50
# |   |   |   |   |--- MonthlyRate <= 16767.50
# |   |   |   |   |   |--- RelationshipSatisfaction <= 1.50
# |   |   |   |   |   |   |--- TotalWorkingYears <= 3.50
# |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |--- TotalWorkingYears >  3.50
# |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |--- RelationshipSatisfaction >  1.50
# |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |--- MonthlyRate >  16767.50
# |   |   |   |   |   |--- HourlyRate <= 45.50
# |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |--- HourlyRate >  45.50
# |   |   |   |   |   |   |--- class: No
# |   |   |   |--- YearsInCurrentRole >  2.50
# |   |   |   |   |--- class: No
# |   |--- MonthlyIncome >  2475.00
# |   |   |--- MaritalStatus_Single <= 0.50
# |   |   |   |--- JobLevel <= 1.50
# |   |   |   |   |--- MonthlyRate <= 16643.50
# |   |   |   |   |   |--- Department_Sales <= 0.50
# |   |   |   |   |   |   |--- YearsAtCompany <= 0.50
# |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |--- YearsAtCompany >  0.50
# |   |   |   |   |   |   |   |--- MonthlyIncome <= 4864.50
# |   |   |   |   |   |   |   |   |--- WorkLifeBalance <= 1.50
# |   |   |   |   |   |   |   |   |   |--- YearsAtCompany <= 3.00
# |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |   |--- YearsAtCompany >  3.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |--- WorkLifeBalance >  1.50
# |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |--- MonthlyIncome >  4864.50
# |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |--- Department_Sales >  0.50
# |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |--- MonthlyRate >  16643.50
# |   |   |   |   |   |--- JobRole_Research Scientist <= 0.50
# |   |   |   |   |   |   |--- MonthlyIncome <= 2700.00
# |   |   |   |   |   |   |   |--- Education <= 2.00
# |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |--- Education >  2.00
# |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |--- MonthlyIncome >  2700.00
# |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |--- JobRole_Research Scientist >  0.50
# |   |   |   |   |   |   |--- NumCompaniesWorked <= 4.50
# |   |   |   |   |   |   |   |--- YearsInCurrentRole <= 0.50
# |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |--- YearsInCurrentRole >  0.50
# |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |--- NumCompaniesWorked >  4.50
# |   |   |   |   |   |   |   |--- YearsInCurrentRole <= 1.00
# |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |--- YearsInCurrentRole >  1.00
# |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |--- JobLevel >  1.50
# |   |   |   |   |--- DistanceFromHome <= 21.50
# |   |   |   |   |   |--- MonthlyIncome <= 19853.00
# |   |   |   |   |   |   |--- Age <= 23.00
# |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |--- Age >  23.00
# |   |   |   |   |   |   |   |--- TrainingTimesLastYear <= 0.50
# |   |   |   |   |   |   |   |   |--- Gender_Female <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |--- Gender_Female >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |--- TrainingTimesLastYear >  0.50
# |   |   |   |   |   |   |   |   |--- MonthlyRate <= 24606.50
# |   |   |   |   |   |   |   |   |   |--- TrainingTimesLastYear <= 5.50
# |   |   |   |   |   |   |   |   |   |   |--- StockOptionLevel <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- StockOptionLevel >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |   |--- TrainingTimesLastYear >  5.50
# |   |   |   |   |   |   |   |   |   |   |--- MonthlyIncome <= 9040.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |   |   |--- MonthlyIncome >  9040.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |--- MonthlyRate >  24606.50
# |   |   |   |   |   |   |   |   |   |--- EnvironmentSatisfaction <= 2.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |   |--- EnvironmentSatisfaction >  2.50
# |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |--- MonthlyIncome >  19853.00
# |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |--- DistanceFromHome >  21.50
# |   |   |   |   |   |--- YearsInCurrentRole <= 7.50
# |   |   |   |   |   |   |--- Gender_Female <= 0.50
# |   |   |   |   |   |   |   |--- EducationField_Technical Degree <= 0.50
# |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |--- EducationField_Technical Degree >  0.50
# |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |--- Gender_Female >  0.50
# |   |   |   |   |   |   |   |--- JobRole_Human Resources <= 0.50
# |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |--- JobRole_Human Resources >  0.50
# |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |--- YearsInCurrentRole >  7.50
# |   |   |   |   |   |   |--- class: No
# |   |   |--- MaritalStatus_Single >  0.50
# |   |   |   |--- YearsSinceLastPromotion <= 5.50
# |   |   |   |   |--- HourlyRate <= 53.50
# |   |   |   |   |   |--- class: No
# |   |   |   |   |--- HourlyRate >  53.50
# |   |   |   |   |   |--- YearsAtCompany <= 2.50
# |   |   |   |   |   |   |--- JobRole_Manufacturing Director <= 0.50
# |   |   |   |   |   |   |   |--- HourlyRate <= 78.00
# |   |   |   |   |   |   |   |   |--- EnvironmentSatisfaction <= 1.50
# |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |--- EnvironmentSatisfaction >  1.50
# |   |   |   |   |   |   |   |   |   |--- JobRole_Laboratory Technician <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |   |--- JobRole_Laboratory Technician >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |--- HourlyRate >  78.00
# |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |--- JobRole_Manufacturing Director >  0.50
# |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |--- YearsAtCompany >  2.50
# |   |   |   |   |   |   |--- TrainingTimesLastYear <= 3.50
# |   |   |   |   |   |   |   |--- RelationshipSatisfaction <= 1.50
# |   |   |   |   |   |   |   |   |--- HourlyRate <= 75.50
# |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |--- HourlyRate >  75.50
# |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |--- RelationshipSatisfaction >  1.50
# |   |   |   |   |   |   |   |   |--- JobInvolvement <= 3.50
# |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |--- JobInvolvement >  3.50
# |   |   |   |   |   |   |   |   |   |--- EnvironmentSatisfaction <= 3.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |   |--- EnvironmentSatisfaction >  3.00
# |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |--- TrainingTimesLastYear >  3.50
# |   |   |   |   |   |   |   |--- BusinessTravel_Travel_Frequently <= 0.50
# |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |--- BusinessTravel_Travel_Frequently >  0.50
# |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |--- YearsSinceLastPromotion >  5.50
# |   |   |   |   |--- HourlyRate <= 86.00
# |   |   |   |   |   |--- class: Yes
# |   |   |   |   |--- HourlyRate >  86.00
# |   |   |   |   |   |--- class: No
# |--- OverTime_No >  0.50
# |   |--- TotalWorkingYears <= 1.50
# |   |   |--- BusinessTravel_Travel_Frequently <= 0.50
# |   |   |   |--- DailyRate <= 249.50
# |   |   |   |   |--- class: Yes
# |   |   |   |--- DailyRate >  249.50
# |   |   |   |   |--- WorkLifeBalance <= 2.50
# |   |   |   |   |   |--- Age <= 27.00
# |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |--- Age >  27.00
# |   |   |   |   |   |   |--- JobRole_Sales Representative <= 0.50
# |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |--- JobRole_Sales Representative >  0.50
# |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |--- WorkLifeBalance >  2.50
# |   |   |   |   |   |--- EducationField_Marketing <= 0.50
# |   |   |   |   |   |   |--- MonthlyRate <= 24318.50
# |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |--- MonthlyRate >  24318.50
# |   |   |   |   |   |   |   |--- DailyRate <= 1175.50
# |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |--- DailyRate >  1175.50
# |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |--- EducationField_Marketing >  0.50
# |   |   |   |   |   |   |--- class: Yes
# |   |   |--- BusinessTravel_Travel_Frequently >  0.50
# |   |   |   |--- JobRole_Research Scientist <= 0.50
# |   |   |   |   |--- class: Yes
# |   |   |   |--- JobRole_Research Scientist >  0.50
# |   |   |   |   |--- class: No
# |   |--- TotalWorkingYears >  1.50
# |   |   |--- StockOptionLevel <= 0.50
# |   |   |   |--- JobSatisfaction <= 1.50
# |   |   |   |   |--- DistanceFromHome <= 8.50
# |   |   |   |   |   |--- MonthlyIncome <= 3263.00
# |   |   |   |   |   |   |--- MonthlyIncome <= 2955.00
# |   |   |   |   |   |   |   |--- NumCompaniesWorked <= 3.50
# |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |--- NumCompaniesWorked >  3.50
# |   |   |   |   |   |   |   |   |--- MonthlyIncome <= 2709.50
# |   |   |   |   |   |   |   |   |   |--- DailyRate <= 176.00
# |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |   |--- DailyRate >  176.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |--- MonthlyIncome >  2709.50
# |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |--- MonthlyIncome >  2955.00
# |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |--- MonthlyIncome >  3263.00
# |   |   |   |   |   |   |--- class: No
# |   |   |   |   |--- DistanceFromHome >  8.50
# |   |   |   |   |   |--- NumCompaniesWorked <= 2.50
# |   |   |   |   |   |   |--- DailyRate <= 419.00
# |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |--- DailyRate >  419.00
# |   |   |   |   |   |   |   |--- BusinessTravel_Travel_Rarely <= 0.50
# |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |--- BusinessTravel_Travel_Rarely >  0.50
# |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |--- NumCompaniesWorked >  2.50
# |   |   |   |   |   |   |--- Age <= 54.50
# |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |--- Age >  54.50
# |   |   |   |   |   |   |   |--- class: No
# |   |   |   |--- JobSatisfaction >  1.50
# |   |   |   |   |--- JobInvolvement <= 1.50
# |   |   |   |   |   |--- RelationshipSatisfaction <= 1.50
# |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |--- RelationshipSatisfaction >  1.50
# |   |   |   |   |   |   |--- PercentSalaryHike <= 17.50
# |   |   |   |   |   |   |   |--- JobRole_Research Scientist <= 0.50
# |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |--- JobRole_Research Scientist >  0.50
# |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |--- PercentSalaryHike >  17.50
# |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |--- JobInvolvement >  1.50
# |   |   |   |   |   |--- YearsSinceLastPromotion <= 14.00
# |   |   |   |   |   |   |--- YearsInCurrentRole <= 2.50
# |   |   |   |   |   |   |   |--- YearsSinceLastPromotion <= 5.50
# |   |   |   |   |   |   |   |   |--- EducationField_Technical Degree <= 0.50
# |   |   |   |   |   |   |   |   |   |--- TotalWorkingYears <= 5.50
# |   |   |   |   |   |   |   |   |   |   |--- NumCompaniesWorked <= 4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- NumCompaniesWorked >  4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- TotalWorkingYears >  5.50
# |   |   |   |   |   |   |   |   |   |   |--- DailyRate <= 1468.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |   |   |--- DailyRate >  1468.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- EducationField_Technical Degree >  0.50
# |   |   |   |   |   |   |   |   |   |--- MonthlyRate <= 20700.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |   |--- MonthlyRate >  20700.00
# |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |--- YearsSinceLastPromotion >  5.50
# |   |   |   |   |   |   |   |   |--- MonthlyRate <= 22016.00
# |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |--- MonthlyRate >  22016.00
# |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |--- YearsInCurrentRole >  2.50
# |   |   |   |   |   |   |   |--- JobRole_Sales Executive <= 0.50
# |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |--- JobRole_Sales Executive >  0.50
# |   |   |   |   |   |   |   |   |--- Age <= 45.50
# |   |   |   |   |   |   |   |   |   |--- JobSatisfaction <= 2.50
# |   |   |   |   |   |   |   |   |   |   |--- EnvironmentSatisfaction <= 2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |   |   |--- EnvironmentSatisfaction >  2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |   |--- JobSatisfaction >  2.50
# |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |--- Age >  45.50
# |   |   |   |   |   |   |   |   |   |--- MonthlyIncome <= 11745.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |   |--- MonthlyIncome >  11745.50
# |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |--- YearsSinceLastPromotion >  14.00
# |   |   |   |   |   |   |--- class: Yes
# |   |   |--- StockOptionLevel >  0.50
# |   |   |   |--- YearsAtCompany <= 31.50
# |   |   |   |   |--- DailyRate <= 1495.50
# |   |   |   |   |   |--- YearsAtCompany <= 1.50
# |   |   |   |   |   |   |--- EmployeeNumber <= 74.00
# |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |--- EmployeeNumber >  74.00
# |   |   |   |   |   |   |   |--- JobRole_Manufacturing Director <= 0.50
# |   |   |   |   |   |   |   |   |--- DistanceFromHome <= 14.00
# |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |--- DistanceFromHome >  14.00
# |   |   |   |   |   |   |   |   |   |--- DistanceFromHome <= 17.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |   |--- DistanceFromHome >  17.00
# |   |   |   |   |   |   |   |   |   |   |--- HourlyRate <= 95.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |   |   |--- HourlyRate >  95.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |--- JobRole_Manufacturing Director >  0.50
# |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |--- YearsAtCompany >  1.50
# |   |   |   |   |   |   |--- EmployeeNumber <= 2028.50
# |   |   |   |   |   |   |   |--- JobRole_Human Resources <= 0.50
# |   |   |   |   |   |   |   |   |--- JobRole_Laboratory Technician <= 0.50
# |   |   |   |   |   |   |   |   |   |--- PercentSalaryHike <= 11.50
# |   |   |   |   |   |   |   |   |   |   |--- JobRole_Healthcare Representative <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- JobRole_Healthcare Representative >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- PercentSalaryHike >  11.50
# |   |   |   |   |   |   |   |   |   |   |--- DailyRate <= 122.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- DailyRate >  122.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |--- JobRole_Laboratory Technician >  0.50
# |   |   |   |   |   |   |   |   |   |--- HourlyRate <= 34.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |   |--- HourlyRate >  34.50
# |   |   |   |   |   |   |   |   |   |   |--- MonthlyRate <= 6733.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- MonthlyRate >  6733.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |--- JobRole_Human Resources >  0.50
# |   |   |   |   |   |   |   |   |--- TrainingTimesLastYear <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |--- TrainingTimesLastYear >  0.50
# |   |   |   |   |   |   |   |   |   |--- TotalWorkingYears <= 20.00
# |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |   |--- TotalWorkingYears >  20.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |--- EmployeeNumber >  2028.50
# |   |   |   |   |   |   |   |--- NumCompaniesWorked <= 5.50
# |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |--- NumCompaniesWorked >  5.50
# |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |--- DailyRate >  1495.50
# |   |   |   |   |   |--- RelationshipSatisfaction <= 2.50
# |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |--- RelationshipSatisfaction >  2.50
# |   |   |   |   |   |   |--- class: Yes
# |   |   |   |--- YearsAtCompany >  31.50
# |   |   |   |   |--- Gender_Female <= 0.50
# |   |   |   |   |   |--- class: No
# |   |   |   |   |--- Gender_Female >  0.50
# |   |   |   |   |   |--- class: Yes
